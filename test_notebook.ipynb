# %% [markdown]
# Test notebook for playing with octis

# %%
import octis
octis.__version__
# Out:
# '1.13.1'

# %% [markdown]
# Loading datasets.  We'll be using one or more for training and a custom one for transfer learning (possibly meta-learning with distance metrics if performance isn't great)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Question:** How are these datasets preprocessed?

# %%
from octis.dataset.dataset import Dataset
dataset_news = Dataset()
dataset_news.fetch_dataset("20NewsGroup")

dataset_bbc = Dataset()
dataset_bbc.fetch_dataset("BBC_News")

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://github.com/MIND-Lab/OCTIS/tree/master/preprocessed_datasets/sample_dataset

# %%
#from octis.dataset.dataset import Dataset
#dataset = Dataset()
#dataset.load_custom_dataset_from_folder("../path/to/the/dataset/folder")

# %%
from octis.dataset.dataset import Dataset
from octis.models.ETM import ETM
#from octis.models.ETM_TL import ETM

model = LDA(num_topics=25)  # Create model
model_output = model.train_model(dataset) # Train the model
